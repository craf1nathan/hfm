# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 1 — Bootstrap                                  ║
# ╚══════════════════════════════════════════════════════╝
import sys
from pathlib import Path

# ── Make src/ importable from notebooks/ ─────────────────
PROJECT_ROOT = Path("..").resolve()        # project/ absolute path
sys.path.insert(0, str(PROJECT_ROOT))

# ── Config paths (absolute → no cwd ambiguity) ────────────
DATA_CFG     = str(PROJECT_ROOT / "config" / "data_config.json")
PIPELINE_CFG = str(PROJECT_ROOT / "config" / "pipeline_config.json")

print(f"Project root : {PROJECT_ROOT}")
print(f"Data config  : {DATA_CFG}")
print(f"Pipeline cfg : {PIPELINE_CFG}")
# Out:
# Project root : /storage/emulated/0/Github/hfm
# Data config  : /storage/emulated/0/Github/hfm/config/data_config.json
# Pipeline cfg : /storage/emulated/0/Github/hfm/config/pipeline_config.json

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 2 — Run pipeline                               ║
# ╚══════════════════════════════════════════════════════╝
from src.phase1_data_pipeline import run_pipeline

splits, master, reports = run_pipeline(
    data_cfg_path     = DATA_CFG,
    pipeline_cfg_path = PIPELINE_CFG,
    verbose           = True
)
# Out:
# ────────────────────────────────────────────────────────────
#   PHASE 1 — DATA PIPELINE
# ────────────────────────────────────────────────────────────
#   data_folder : /storage/emulated/0/Github/hfm/data
#
# [·] Loading & cleaning target
#     [TARGET] XAUUSD     raw=   20,000  clean=   18,920  dupes=   0  wknd= 1,080  bad_px=  0
#
# [·] Loading & cleaning predictors
#     [PRED  ] BCOUSD     raw=   20,000  clean=   19,309  dupes=   0  wknd=   691  bad_px=  0
#     [PRED  ] USDJPY     raw=   20,000  clean=   18,752  dupes=   0  wknd= 1,248  bad_px=  0
#     [PRED  ] EURUSD     raw=   20,000  clean=   18,750  dupes=   0  wknd= 1,250  bad_px=  0
#     [PRED  ] NSXUSD     raw=   20,000  clean=   18,920  dupes=   0  wknd= 1,080  bad_px=  0
#     [PRED  ] SPXUSD     raw=   20,000  clean=   18,925  dupes=   0  wknd= 1,075  bad_px=  0
#     [PRED  ] UDXUSD     raw=   20,000  clean=   19,301  dupes=   0  wknd=   699  bad_px=  0
#     [PRED  ] XAGUSD     raw=   20,000  clean=   18,940  dupes=   0  wknd= 1,060  bad_px=  0
#
# [·] Aligning to master clock (target index)
#          shape : (18920, 48)
#          range : 2025-12-10 02:17:00+00:00  →  2025-12-31 16:57:00+00:00
#
# [·] Assigning session labels
#          [0] Dead_zone    :      1,680 bars
#          [1] Asian        :      5,383 bars
#          [2] London       :      3,600 bars
#          [3] Overlap      :      3,464 bars
#          [4] New_York     :      2,153 bars
#          [5] Late_NY      :      2,640 bars
#
# [·] Splitting data
#          train        :   11,562 bars  2025-12-10 02:17:00+00:00  →  2025-12-22 23:59:00+00:00
#          validation   :    3,580 bars  2025-12-23 00:00:00+00:00  →  2025-12-26 16:59:00+00:00
#          test         :    3,778 bars  2025-12-29 00:00:00+00:00  →  2025-12-31 16:57:00+00:00  ⚠️  SACRED
#
# ────────────────────────────────────────────────────────────
#   PHASE 1 COMPLETE
# ────────────────────────────────────────────────────────────

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 3 — Master DataFrame overview                  ║
# ╚══════════════════════════════════════════════════════╝
print(f"Shape   : {master.shape}")
print(f"Columns : {list(master.columns)}\n")
master.head(3)
# Out:
# Shape   : (18920, 49)
# Columns : ['open', 'high', 'low', 'close', 'volume', 'is_filled', 'BCOUSD_open', 'BCOUSD_high', 'BCOUSD_low', 'BCOUSD_close', 'BCOUSD_volume', 'BCOUSD_is_filled', 'USDJPY_open', 'USDJPY_high', 'USDJPY_low', 'USDJPY_close', 'USDJPY_volume', 'USDJPY_is_filled', 'EURUSD_open', 'EURUSD_high', 'EURUSD_low', 'EURUSD_close', 'EURUSD_volume', 'EURUSD_is_filled', 'NSXUSD_open', 'NSXUSD_high', 'NSXUSD_low', 'NSXUSD_close', 'NSXUSD_volume', 'NSXUSD_is_filled', 'SPXUSD_open', 'SPXUSD_high', 'SPXUSD_low', 'SPXUSD_close', 'SPXUSD_volume', 'SPXUSD_is_filled', 'UDXUSD_open', 'UDXUSD_high', 'UDXUSD_low', 'UDXUSD_close', 'UDXUSD_volume', 'UDXUSD_is_filled', 'XAGUSD_open', 'XAGUSD_high', 'XAGUSD_low', 'XAGUSD_close', 'XAGUSD_volume', 'XAGUSD_is_filled', 'session']
#                                open      high       low     close  volume  \
# timestamp
# 2025-12-10 02:17:00+00:00  4206.515  4206.895  4206.295  4206.875       0
# 2025-12-10 02:18:00+00:00  4206.925  4208.285  4206.825  4208.285       0
# 2025-12-10 02:19:00+00:00  4208.435  4208.775  4207.745  4207.935       0
#
#                            is_filled  BCOUSD_open  BCOUSD_high  BCOUSD_low  \
# timestamp
# 2025-12-10 02:17:00+00:00          0       62.105       62.105      62.075
# 2025-12-10 02:18:00+00:00          0       62.085       62.090      62.080
# 2025-12-10 02:19:00+00:00          0       62.072       62.072      62.055
#
#                            BCOUSD_close  ...  UDXUSD_close  UDXUSD_volume  \
# timestamp                                ...
# 2025-12-10 02:17:00+00:00        62.080  ...        99.100            0.0
# 2025-12-10 02:18:00+00:00        62.080  ...        99.106            0.0
# 2025-12-10 02:19:00+00:00        62.065  ...        99.095            0.0
#
#                            UDXUSD_is_filled  XAGUSD_open  XAGUSD_high  \
# timestamp
# 2025-12-10 02:17:00+00:00                 0       61.399       61.427
# 2025-12-10 02:18:00+00:00                 0       61.419       61.477
# 2025-12-10 02:19:00+00:00                 0       61.476       61.486
#
#                            XAGUSD_low  XAGUSD_close  XAGUSD_volume  \
# timestamp
# 2025-12-10 02:17:00+00:00      61.379        61.414            0.0
# 2025-12-10 02:18:00+00:00      61.409        61.473            0.0
# 2025-12-10 02:19:00+00:00      61.460        61.477            0.0
#
#                            XAGUSD_is_filled  session
# timestamp
# 2025-12-10 02:17:00+00:00                 0        1
# 2025-12-10 02:18:00+00:00                 0        1
# 2025-12-10 02:19:00+00:00                 0        1
#
# [3 rows x 49 columns]

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 4 — Split sizes                                ║
# ╚══════════════════════════════════════════════════════╝
for name, df in splits.items():
    print(f"{name:<12}: {len(df):>8,} bars   "
          f"{df.index[0]}  →  {df.index[-1]}")
# Out:
# train       :   11,562 bars   2025-12-10 02:17:00+00:00  →  2025-12-22 23:59:00+00:00
# validation  :    3,580 bars   2025-12-23 00:00:00+00:00  →  2025-12-26 16:59:00+00:00
# test        :    3,778 bars   2025-12-29 00:00:00+00:00  →  2025-12-31 16:57:00+00:00

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 5 — Cleaning report                            ║
# ╚══════════════════════════════════════════════════════╝
pd.DataFrame(reports).T
# Out:
#         symbol raw_bars duplicates_removed weekend_bars_removed  \
# XAUUSD  XAUUSD    20000                  0                 1080
# BCOUSD  BCOUSD    20000                  0                  691
# USDJPY  USDJPY    20000                  0                 1248
# EURUSD  EURUSD    20000                  0                 1250
# NSXUSD  NSXUSD    20000                  0                 1080
# SPXUSD  SPXUSD    20000                  0                 1075
# UDXUSD  UDXUSD    20000                  0                  699
# XAGUSD  XAGUSD    20000                  0                 1060
#
#        bad_price_bars_removed clean_bars
# XAUUSD                      0      18920
# BCOUSD                      0      19309
# USDJPY                      0      18752
# EURUSD                      0      18750
# NSXUSD                      0      18920
# SPXUSD                      0      18925
# UDXUSD                      0      19301
# XAGUSD                      0      18940

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 6 — NaN audit (session breaks)                 ║
# ╚══════════════════════════════════════════════════════╝
nan_counts = master.isna().sum()
nan_counts = nan_counts[nan_counts > 0]

if nan_counts.empty:
    print("No NaN values — all gaps were within max_fill_gap.")
else:
    print("Columns with NaN (gaps > max_fill_gap = session breaks):")
    print(nan_counts.to_string())
# Out:
# Columns with NaN (gaps > max_fill_gap = session breaks):
# BCOUSD_open      1649
# BCOUSD_high      1649
# BCOUSD_low       1649
# BCOUSD_close     1649
# BCOUSD_volume    1649
# USDJPY_open      1312
# USDJPY_high      1312
# USDJPY_low       1312
# USDJPY_close     1312
# USDJPY_volume    1312
# EURUSD_open      1111
# EURUSD_high      1111
# EURUSD_low       1111
# EURUSD_close     1111
# EURUSD_volume    1111
# NSXUSD_open       585
# NSXUSD_high       585
# NSXUSD_low        585
# NSXUSD_close      585
# NSXUSD_volume     585
# SPXUSD_open       585
# SPXUSD_high       585
# SPXUSD_low        585
# SPXUSD_close      585
# SPXUSD_volume     585
# UDXUSD_open      1280
# UDXUSD_high      1280
# UDXUSD_low       1280
# UDXUSD_close     1280
# UDXUSD_volume    1280

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 7 — Forward-fill audit                         ║
# ╚══════════════════════════════════════════════════════╝
fill_cols = [c for c in master.columns if c.endswith("_is_filled")]
fill_totals = master[fill_cols].sum().rename("filled_bars")
fill_pct    = (fill_totals / len(master) * 100).rename("fill_%")
pd.concat([fill_totals, fill_pct], axis=1).round(2)
# Out:
#                   filled_bars  fill_%
# BCOUSD_is_filled          486    2.57
# USDJPY_is_filled           10    0.05
# EURUSD_is_filled           45    0.24
# NSXUSD_is_filled           75    0.40
# SPXUSD_is_filled          165    0.87
# UDXUSD_is_filled          421    2.23
# XAGUSD_is_filled           51    0.27

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 8 — Session distribution per split             ║
# ╚══════════════════════════════════════════════════════╝
_, pipeline_cfg = load_configs(
    "../config/data_config.json",
    "../config/pipeline_config.json"
)
session_names = {
    int(k): v["name"]
    for k, v in pipeline_cfg["sessions"].items()
}

for name, df in splits.items():
    dist = (
        df["session"]
        .value_counts()
        .sort_index()
        .rename(index=session_names)
    )
    print(f"\n── {name} ──────────────────")
    print(dist.to_string())
# Out:
# ── train ──────────────────
# session
# Dead_zone     960
# Asian        3223
# London       2160
# Overlap      2160
# New_York     1379
# Late_NY      1680
#
# ── validation ──────────────────
# session
# Dead_zone     360
# Asian        1080
# London        720
# Overlap       584
# New_York      356
# Late_NY       480
#
# ── test ──────────────────
# session
# Dead_zone     360
# Asian        1080
# London        720
# Overlap       720
# New_York      418
# Late_NY       480

# %%
# ╔══════════════════════════════════════════════════════╗
# ║  Cell 9 — Sanity plot                                ║
# ╚══════════════════════════════════════════════════════╝
COLORS = {"train": "green", "validation": "orange", "test": "red"}

fig, ax = plt.subplots(figsize=(15, 3))
master["close"].plot(ax=ax, lw=0.4, color="steelblue", label="Target close")

for name, df in splits.items():
    ax.axvspan(
        df.index[0], df.index[-1],
        alpha=0.12,
        color=COLORS[name],
        label=name
    )

ax.set_title("Target Close — Train / Validation / Test regions")
ax.legend(loc="upper left")
plt.tight_layout()
plt.show()
